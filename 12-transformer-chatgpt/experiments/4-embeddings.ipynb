# %%
import torch

vocab_size = 10 # "what", "is", "statquest", "<EOS>", "awesome"
embedding_dim = 2 # how many numbers to use to represent each token

we = torch.nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_dim)
print(we.weight.shape)
# Out:
# torch.Size([10, 2])
